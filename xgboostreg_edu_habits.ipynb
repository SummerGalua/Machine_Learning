# %% [markdown]
# # Librerías y datos del programa

# %%
# Python 3.12.10 - author: Carlos Brandon Cortes Cortina 
import kagglehub
import pandas as pd
import numpy as np 
import scipy.stats as stats
import os
import shutil
from sklearn.model_selection import train_test_split, KFold, GridSearchCV,cross_val_score
from sklearn.feature_selection import RFECV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from  xgboost import XGBRegressor

# %% [markdown]
# # Ajustes de la Data

# %%
# Descargar el dataset
pathd = kagglehub.dataset_download("jayaantanaath/student-habits-vs-academic-performance")
print("Path to dataset files:", pathd)

# Normalizar path
pathd = pathd.replace("\\", "/")

# Ruta destino
dest_folder = "C:/DB/Student-Habits-vs-Academic-Performance"
dest_file = os.path.join(dest_folder, "student_habits_performance.csv")

# Crear carpeta de destino si no existe
os.makedirs(dest_folder, exist_ok=True)

# Ruta del archivo descargado
source_file = os.path.join(pathd, "student_habits_performance.csv")

# Mover archivo si no existe ya en destino
if not os.path.exists(dest_file):
    shutil.move(source_file, dest_file)
    print("Archivo movido exitosamente.")
else:
    print("El archivo ya existe en la carpeta destino.")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: C:\Users\brand\.cache\kagglehub\datasets\jayaantanaath\student-habits-vs-academic-performance\versions\1
# El archivo ya existe en la carpeta destino.

# %%
data = pd.read_csv("C:/DB/Student-Habits-vs-Academic-Performance/student_habits_performance.csv")
data.head()
# Out:
#   student_id  age  ... extracurricular_participation  exam_score
# 0      S1000   23  ...                           Yes        56.2
# 1      S1001   20  ...                            No       100.0
# 2      S1002   21  ...                            No        34.3
# 3      S1003   23  ...                           Yes        26.8
# 4      S1004   19  ...                            No        66.4
#
# [5 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %% [markdown]
# # Selección de características e hiperparámetros

# %%
seed = 42
kf = KFold(n_splits = 10, shuffle = True, random_state = seed)
model = XGBRegressor(random_state = seed)

#Identificación de variables dependientes y la target
x_train = data.drop(columns=['exam_score','student_id'])
x_train = pd.get_dummies(x_train,drop_first = True, dtype = int)
y_train = data['exam_score']

#Partimos la data para predecir más adelante el 20% de los datos y comparar con los registros reales 
X_train,X_test,Y_train,Y_test = train_test_split(x_train,y_train,test_size = 0.2,random_state = seed)

# %%
#Selección de características
selector = RFECV(estimator=model, step=1, cv=kf, scoring = 'neg_mean_squared_error')
selector.fit(X_train,Y_train)
features = selector.get_feature_names_out()
print(f'Las variables elegidas son las siguientes:{features}')
x_train = x_train[features]
# Out:
# Las variables elegidas son las siguientes:['study_hours_per_day' 'social_media_hours' 'netflix_hours'
#  'attendance_percentage' 'sleep_hours' 'exercise_frequency'
#  'mental_health_rating' 'gender_Male' 'part_time_job_Yes'
#  'parental_education_level_Master' 'internet_quality_Good'
#  'internet_quality_Poor' 'extracurricular_participation_Yes']

# %%
# Una vez seleccionadas as características, ajustaremos el modelo con estas características para calcular los 
# hiperparámetros

search_space = {
    "n_estimators" : [100, 200, 500],
    "max_depth" : [3, 6, 9],
    "gamma" : [0.01, 0.1],
    "learning_rate" : [0.001, 0.01, 0.1, 1]
}

GS = GridSearchCV(estimator = model,
            param_grid = search_space,
            scoring = ["r2", "neg_root_mean_squared_error"], 
            refit = "r2",
            cv = kf,
            verbose = 4)
GS.fit(X_train,Y_train)

best_estimator = GS.best_estimator_
best_params = GS.best_params_
best_score = GS.best_score_
results = pd.DataFrame(GS.cv_results_)
results = results.sort_values('rank_test_r2')
results = results.to_csv()
print(f'Hiperparámetros:\n{best_params}\nbest_score:{best_score}')
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.043) r2: (test=0.130) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.035) r2: (test=0.131) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.130) r2: (test=0.133) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.001) r2: (test=0.133) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-17.675) r2: (test=0.118) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.444) r2: (test=0.129) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-16.936) r2: (test=0.063) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.426) r2: (test=0.126) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.052) r2: (test=0.112) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-15.768) r2: (test=0.101) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.022) r2: (test=0.237) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.995) r2: (test=0.240) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.164) r2: (test=0.240) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-13.971) r2: (test=0.248) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-16.558) r2: (test=0.226) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.430) r2: (test=0.233) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-15.982) r2: (test=0.165) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.481) r2: (test=0.230) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.125) r2: (test=0.218) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-14.858) r2: (test=0.202) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.581) r2: (test=0.465) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.590) r2: (test=0.464) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-11.919) r2: (test=0.462) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-11.557) r2: (test=0.485) total time=   0.2s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.919) r2: (test=0.453) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.988) r2: (test=0.457) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-13.683) r2: (test=0.388) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.269) r2: (test=0.447) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-11.893) r2: (test=0.446) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-12.665) r2: (test=0.420) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.925) r2: (test=0.142) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.938) r2: (test=0.142) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.137) r2: (test=0.132) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-14.889) r2: (test=0.146) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-17.542) r2: (test=0.131) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-16.378) r2: (test=0.136) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-16.742) r2: (test=0.084) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.433) r2: (test=0.126) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-14.942) r2: (test=0.125) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-15.599) r2: (test=0.120) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.787) r2: (test=0.261) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.821) r2: (test=0.258) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.082) r2: (test=0.249) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-13.776) r2: (test=0.269) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-16.263) r2: (test=0.253) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-15.262) r2: (test=0.250) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-15.631) r2: (test=0.202) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.490) r2: (test=0.229) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-13.993) r2: (test=0.233) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-14.546) r2: (test=0.235) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.070) r2: (test=0.507) total time=   0.4s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.142) r2: (test=0.502) total time=   0.6s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.524) r2: (test=0.497) total time=   0.4s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.075) r2: (test=0.527) total time=   0.4s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-13.233) r2: (test=0.505) total time=   0.4s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.710) r2: (test=0.480) total time=   0.4s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-13.038) r2: (test=0.444) total time=   0.4s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.282) r2: (test=0.446) total time=   0.4s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-11.725) r2: (test=0.461) total time=   0.4s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-12.075) r2: (test=0.473) total time=   0.4s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.908) r2: (test=0.144) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.881) r2: (test=0.148) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.165) r2: (test=0.129) total time=   0.2s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.861) r2: (test=0.149) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-17.554) r2: (test=0.130) total time=   0.2s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-16.397) r2: (test=0.134) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-16.753) r2: (test=0.083) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.457) r2: (test=0.123) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-14.945) r2: (test=0.125) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-15.686) r2: (test=0.110) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.771) r2: (test=0.262) total time=   0.3s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.709) r2: (test=0.269) total time=   0.4s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.171) r2: (test=0.239) total time=   0.4s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-13.745) r2: (test=0.272) total time=   0.3s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-16.316) r2: (test=0.248) total time=   0.3s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-15.305) r2: (test=0.246) total time=   0.3s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-15.684) r2: (test=0.196) total time=   0.3s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.489) r2: (test=0.229) total time=   0.3s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-13.998) r2: (test=0.232) total time=   0.3s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-14.708) r2: (test=0.218) total time=   0.3s
# [CV 1/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.116) r2: (test=0.504) total time=   1.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.101) r2: (test=0.505) total time=   0.9s
# [CV 3/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.681) r2: (test=0.483) total time=   1.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.156) r2: (test=0.521) total time=   1.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.277) r2: (test=0.502) total time=   1.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.862) r2: (test=0.467) total time=   0.9s
# [CV 7/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-13.178) r2: (test=0.432) total time=   1.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.235) r2: (test=0.450) total time=   1.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-11.698) r2: (test=0.464) total time=   1.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-12.280) r2: (test=0.455) total time=   1.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.088) r2: (test=0.656) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.078) r2: (test=0.657) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.651) r2: (test=0.647) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.123) r2: (test=0.679) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.129) r2: (test=0.650) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.466) r2: (test=0.647) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-11.302) r2: (test=0.583) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.196) r2: (test=0.618) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.596) r2: (test=0.639) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-10.431) r2: (test=0.607) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.962) r2: (test=0.786) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.860) r2: (test=0.791) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.704) r2: (test=0.775) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.077) r2: (test=0.807) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.605) r2: (test=0.791) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.342) r2: (test=0.776) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-9.181) r2: (test=0.725) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.494) r2: (test=0.735) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.719) r2: (test=0.767) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.465) r2: (test=0.741) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.173) r2: (test=0.871) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.149) r2: (test=0.872) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.061) r2: (test=0.861) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.509) r2: (test=0.883) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.316) r2: (test=0.887) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.380) r2: (test=0.869) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.324) r2: (test=0.825) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.998) r2: (test=0.820) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.050) r2: (test=0.857) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.518) r2: (test=0.846) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.153) r2: (test=0.717) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.263) r2: (test=0.710) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.795) r2: (test=0.707) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.389) r2: (test=0.729) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.945) r2: (test=0.721) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-10.048) r2: (test=0.675) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-10.440) r2: (test=0.644) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-10.024) r2: (test=0.631) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.376) r2: (test=0.656) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.416) r2: (test=0.679) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.813) r2: (test=0.843) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.175) r2: (test=0.826) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.817) r2: (test=0.824) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.354) r2: (test=0.844) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.246) r2: (test=0.852) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.653) r2: (test=0.811) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.311) r2: (test=0.774) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.013) r2: (test=0.764) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.400) r2: (test=0.785) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.190) r2: (test=0.813) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.904) r2: (test=0.882) total time=   0.4s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.592) r2: (test=0.853) total time=   0.4s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.924) r2: (test=0.867) total time=   0.4s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.722) r2: (test=0.874) total time=   0.4s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.289) r2: (test=0.888) total time=   0.6s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.511) r2: (test=0.863) total time=   0.6s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.199) r2: (test=0.831) total time=   0.6s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.917) r2: (test=0.824) total time=   0.5s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.710) r2: (test=0.824) total time=   0.4s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.171) r2: (test=0.862) total time=   0.4s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.288) r2: (test=0.708) total time=   0.2s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.406) r2: (test=0.701) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.128) r2: (test=0.684) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.457) r2: (test=0.724) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.993) r2: (test=0.718) total time=   0.2s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-10.344) r2: (test=0.655) total time=   0.2s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-10.830) r2: (test=0.617) total time=   0.2s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-10.001) r2: (test=0.633) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.517) r2: (test=0.645) total time=   0.2s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.791) r2: (test=0.653) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.273) r2: (test=0.821) total time=   0.4s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.462) r2: (test=0.812) total time=   0.4s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.366) r2: (test=0.794) total time=   0.4s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.565) r2: (test=0.834) total time=   0.4s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.303) r2: (test=0.849) total time=   0.4s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.338) r2: (test=0.776) total time=   0.4s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.851) r2: (test=0.744) total time=   0.4s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.133) r2: (test=0.757) total time=   0.4s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.620) r2: (test=0.773) total time=   0.4s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.926) r2: (test=0.773) total time=   0.4s
# [CV 1/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.365) r2: (test=0.863) total time=   1.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.914) r2: (test=0.838) total time=   1.2s
# [CV 3/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.818) r2: (test=0.824) total time=   1.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.017) r2: (test=0.861) total time=   1.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.416) r2: (test=0.884) total time=   1.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.398) r2: (test=0.824) total time=   1.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.078) r2: (test=0.787) total time=   1.2s
# [CV 8/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.322) r2: (test=0.803) total time=   1.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.054) r2: (test=0.805) total time=   1.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.229) r2: (test=0.811) total time=   1.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.693) r2: (test=0.890) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.764) r2: (test=0.888) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.818) r2: (test=0.872) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.224) r2: (test=0.895) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.543) r2: (test=0.913) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.902) r2: (test=0.888) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.693) r2: (test=0.854) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.621) r2: (test=0.839) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.643) r2: (test=0.875) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-5.935) r2: (test=0.873) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.785) r2: (test=0.887) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.702) r2: (test=0.890) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.787) r2: (test=0.873) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.142) r2: (test=0.898) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.394) r2: (test=0.918) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.019) r2: (test=0.883) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.593) r2: (test=0.858) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.754) r2: (test=0.833) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.703) r2: (test=0.873) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-5.818) r2: (test=0.878) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.892) r2: (test=0.883) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.714) r2: (test=0.890) total time=   0.2s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.128) r2: (test=0.858) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.278) r2: (test=0.893) total time=   0.2s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.729) r2: (test=0.907) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.271) r2: (test=0.873) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.730) r2: (test=0.852) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.798) r2: (test=0.830) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.037) r2: (test=0.857) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-5.989) r2: (test=0.870) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.773) r2: (test=0.887) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.644) r2: (test=0.851) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.869) r2: (test=0.870) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-5.864) r2: (test=0.868) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.018) r2: (test=0.898) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.454) r2: (test=0.866) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.246) r2: (test=0.828) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.875) r2: (test=0.826) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.556) r2: (test=0.832) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-6.069) r2: (test=0.867) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.747) r2: (test=0.888) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.590) r2: (test=0.853) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.948) r2: (test=0.866) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-5.911) r2: (test=0.865) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.110) r2: (test=0.895) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.467) r2: (test=0.865) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.301) r2: (test=0.826) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.888) r2: (test=0.826) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.546) r2: (test=0.832) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-6.081) r2: (test=0.866) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.755) r2: (test=0.888) total time=   0.2s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.604) r2: (test=0.853) total time=   0.2s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.960) r2: (test=0.865) total time=   0.2s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-5.938) r2: (test=0.864) total time=   0.2s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.161) r2: (test=0.893) total time=   0.2s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.475) r2: (test=0.865) total time=   0.2s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.319) r2: (test=0.825) total time=   0.2s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.907) r2: (test=0.825) total time=   0.2s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.554) r2: (test=0.832) total time=   0.2s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-6.066) r2: (test=0.867) total time=   0.2s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.281) r2: (test=0.867) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.738) r2: (test=0.847) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.697) r2: (test=0.830) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.327) r2: (test=0.846) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.466) r2: (test=0.882) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.342) r2: (test=0.826) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.029) r2: (test=0.789) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.340) r2: (test=0.802) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-6.849) r2: (test=0.816) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-7.309) r2: (test=0.807) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.281) r2: (test=0.867) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.738) r2: (test=0.847) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.697) r2: (test=0.830) total time=   0.2s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.327) r2: (test=0.846) total time=   0.2s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.466) r2: (test=0.882) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.342) r2: (test=0.826) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.029) r2: (test=0.789) total time=   0.2s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.340) r2: (test=0.802) total time=   0.2s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.848) r2: (test=0.816) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.309) r2: (test=0.807) total time=   0.2s
# [CV 1/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.281) r2: (test=0.867) total time=   0.2s
# [CV 2/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.738) r2: (test=0.847) total time=   0.2s
# [CV 3/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.697) r2: (test=0.830) total time=   0.2s
# [CV 4/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.327) r2: (test=0.846) total time=   0.2s
# [CV 5/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.466) r2: (test=0.882) total time=   0.2s
# [CV 6/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.342) r2: (test=0.826) total time=   0.2s
# [CV 7/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.029) r2: (test=0.789) total time=   0.2s
# [CV 8/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.340) r2: (test=0.802) total time=   0.2s
# [CV 9/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.848) r2: (test=0.816) total time=   0.2s
# [CV 10/10] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.309) r2: (test=0.807) total time=   0.2s
# [CV 1/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.699) r2: (test=0.848) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.865) r2: (test=0.841) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.553) r2: (test=0.784) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.116) r2: (test=0.805) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.369) r2: (test=0.802) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.705) r2: (test=0.756) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.746) r2: (test=0.804) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.520) r2: (test=0.733) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.110) r2: (test=0.675) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.338) r2: (test=0.749) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.723) r2: (test=0.847) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.962) r2: (test=0.836) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.657) r2: (test=0.778) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.263) r2: (test=0.797) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.619) r2: (test=0.790) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.784) r2: (test=0.752) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.863) r2: (test=0.798) total time=   0.0s
# [CV 8/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.868) r2: (test=0.711) total time=   0.0s
# [CV 9/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-9.297) r2: (test=0.661) total time=   0.0s
# [CV 10/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.506) r2: (test=0.738) total time=   0.0s
# [CV 1/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.734) r2: (test=0.847) total time=   0.1s
# [CV 2/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.009) r2: (test=0.834) total time=   0.1s
# [CV 3/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.597) r2: (test=0.781) total time=   0.1s
# [CV 4/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.275) r2: (test=0.796) total time=   0.1s
# [CV 5/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.626) r2: (test=0.790) total time=   0.1s
# [CV 6/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.787) r2: (test=0.751) total time=   0.1s
# [CV 7/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.875) r2: (test=0.797) total time=   0.1s
# [CV 8/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.837) r2: (test=0.713) total time=   0.1s
# [CV 9/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-9.326) r2: (test=0.659) total time=   0.1s
# [CV 10/10] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.525) r2: (test=0.737) total time=   0.1s
# [CV 1/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.704) r2: (test=0.744) total time=   0.0s
# [CV 2/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.411) r2: (test=0.701) total time=   0.0s
# [CV 3/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.552) r2: (test=0.723) total time=   0.0s
# [CV 4/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.657) r2: (test=0.711) total time=   0.0s
# [CV 5/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.084) r2: (test=0.815) total time=   0.0s
# [CV 6/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.938) r2: (test=0.682) total time=   0.0s
# [CV 7/10] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.446) r2: (test=0.708) total time=   0.0s
# ...
# [CV 7/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.015) r2: (test=0.790) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.270) r2: (test=0.806) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-6.863) r2: (test=0.815) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-7.291) r2: (test=0.808) total time=   0.2s
# [CV 1/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.386) r2: (test=0.862) total time=   0.2s
# [CV 2/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.930) r2: (test=0.838) total time=   0.2s
# [CV 3/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.678) r2: (test=0.831) total time=   0.2s
# [CV 4/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.267) r2: (test=0.849) total time=   0.2s
# [CV 5/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.454) r2: (test=0.882) total time=   0.2s
# [CV 6/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.364) r2: (test=0.825) total time=   0.2s
# [CV 7/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.015) r2: (test=0.790) total time=   0.2s
# [CV 8/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.270) r2: (test=0.806) total time=   0.2s
# [CV 9/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-6.863) r2: (test=0.815) total time=   0.2s
# [CV 10/10] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-7.291) r2: (test=0.808) total time=   0.2s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.657) r2: (test=0.850) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-6.844) r2: (test=0.842) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.725) r2: (test=0.774) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.057) r2: (test=0.808) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.369) r2: (test=0.802) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.705) r2: (test=0.756) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-7.659) r2: (test=0.808) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.520) r2: (test=0.733) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-9.110) r2: (test=0.675) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-8.418) r2: (test=0.744) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-6.808) r2: (test=0.843) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.009) r2: (test=0.834) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.949) r2: (test=0.761) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.177) r2: (test=0.802) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.611) r2: (test=0.791) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.885) r2: (test=0.746) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-7.784) r2: (test=0.802) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.723) r2: (test=0.721) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-9.317) r2: (test=0.660) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-8.426) r2: (test=0.743) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-6.796) r2: (test=0.844) total time=   0.1s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.009) r2: (test=0.834) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.949) r2: (test=0.761) total time=   0.1s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.177) r2: (test=0.802) total time=   0.1s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.611) r2: (test=0.791) total time=   0.1s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.885) r2: (test=0.746) total time=   0.1s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-7.787) r2: (test=0.802) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.723) r2: (test=0.721) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-9.308) r2: (test=0.661) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-8.426) r2: (test=0.743) total time=   0.1s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.977) r2: (test=0.727) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.692) r2: (test=0.683) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.603) r2: (test=0.720) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.633) r2: (test=0.713) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-8.041) r2: (test=0.817) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-10.053) r2: (test=0.675) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.684) r2: (test=0.694) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.755) r2: (test=0.651) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-9.102) r2: (test=0.675) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-7.460) r2: (test=0.799) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.977) r2: (test=0.727) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-9.692) r2: (test=0.683) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.603) r2: (test=0.720) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.633) r2: (test=0.713) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-8.041) r2: (test=0.817) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-10.053) r2: (test=0.675) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-9.684) r2: (test=0.694) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-9.755) r2: (test=0.651) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-9.102) r2: (test=0.675) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-7.460) r2: (test=0.799) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-8.977) r2: (test=0.727) total time=   0.1s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-9.692) r2: (test=0.683) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-8.603) r2: (test=0.720) total time=   0.1s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-8.633) r2: (test=0.713) total time=   0.1s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-8.041) r2: (test=0.817) total time=   0.1s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-10.053) r2: (test=0.675) total time=   0.1s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-9.684) r2: (test=0.694) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-9.755) r2: (test=0.651) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-9.102) r2: (test=0.675) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-7.460) r2: (test=0.799) total time=   0.1s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.711) r2: (test=0.743) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.207) r2: (test=0.714) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.689) r2: (test=0.714) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.263) r2: (test=0.669) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.582) r2: (test=0.792) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.735) r2: (test=0.695) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-10.021) r2: (test=0.672) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.927) r2: (test=0.638) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-8.785) r2: (test=0.698) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-9.583) r2: (test=0.668) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.711) r2: (test=0.743) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-9.207) r2: (test=0.714) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.689) r2: (test=0.714) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-9.263) r2: (test=0.669) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.582) r2: (test=0.792) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-9.735) r2: (test=0.695) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-10.021) r2: (test=0.672) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-9.927) r2: (test=0.638) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-8.785) r2: (test=0.698) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-9.583) r2: (test=0.668) total time=   0.0s
# [CV 1/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.711) r2: (test=0.743) total time=   0.1s
# [CV 2/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-9.207) r2: (test=0.714) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.689) r2: (test=0.714) total time=   0.1s
# [CV 4/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-9.263) r2: (test=0.669) total time=   0.1s
# [CV 5/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.582) r2: (test=0.792) total time=   0.1s
# [CV 6/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-9.735) r2: (test=0.695) total time=   0.1s
# [CV 7/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-10.021) r2: (test=0.672) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-9.927) r2: (test=0.638) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-8.785) r2: (test=0.698) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-9.583) r2: (test=0.668) total time=   0.1s
# Hiperparámetros:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# best_score:0.8790106473771191

# %% [markdown]
# # Ajuste del modelo y análsis de las predicciones

# %%
# Ajustamos el modelo con los hiperparámetros y las característcias óptimas detectadas 
model_final = XGBRegressor(objective= 'reg:squarederror',gamma = 0.01, learning_rate = 0.1, max_depth = 3, n_estimators = 200,random_state = seed)

# %%
model_final.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.01, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
scores = cross_val_score(estimator = model_final, X = X_train, y = Y_train, cv = kf)
np.mean(scores)
# Out:
# 0.8790058959592757

# %%
predicts = model_final.predict(X_test)
mae = mean_absolute_error(Y_test,predicts)
rmse = np.sqrt(mean_squared_error(Y_test,predicts))
r2 = r2_score(Y_test,predicts)
print(f'mae:{mae}\nrmse:{rmse}\nr2:{r2}')
# Out:
# mae:4.5661974601745605
# rmse:5.570508455392681
# r2:0.8789896897986905

# %% [markdown]
# ##### Conclusión: Observamos que las métricas de rendimiento reflejan que el modelo predice con bastante exactitud el desempeño de los alumnos basándase en los hábitos encontrados:
# ##### ['study_hours_per_day' 'social_media_hours' 'netflix_hours''attendance_percentage' 'sleep_hours' 'exercise_frequency''mental_health_rating' 'gender_Male' 'part_time_job_Yes''parental_education_level_Master' 'internet_quality_Good''internet_quality_Poor' 'extracurricular_participation_Yes']
